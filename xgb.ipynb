# %%
import sagemaker
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.session import s3_input, Session

# %%
bucket_name = 'churnbnking1'
my_region = boto3.session.Session().region_name
print(my_region)
# Out:
# us-east-1

# %%
s3 = boto3.resource('s3')
try:
    if my_region == 'us-east-1':
        s3.create_bucket(Bucket=bucket_name)
    print("s3 bucket created successfully")
except Exception as e:
    print("s3 error", e)
# Out:
# s3 bucket created successfully

# %%
prefix = "xgboost_model"
op_path = 's3://{}/{}/output4'.format(bucket_name,prefix)

# %%
import pandas as pd

# %%
df = pd.read_csv("churn.csv")

# %%
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.drop(['CustomerId', 'Surname','Geography'],axis=1,inplace=True)

# %%
df.drop(['Gender'],axis=1,inplace=True)

# %%
import numpy as np

# %%
train_data,test_data = np.split(df.sample(frac=1,random_state=2),[int(0.8*len(df))])

# %%
import os
pd.concat([train_data['Exited'],train_data.drop('Exited',axis=1)],axis=1).to_csv('train.csv', index=False, header=False)

# %%
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.session.s3_input(s3_data = 's3://{}/{}/train'.format(bucket_name,prefix), content_type='csv')
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
pd.concat([test_data['Exited'],test_data.drop('Exited',axis=1)],axis=1).to_csv('test.csv', index=False, header=False)

# %%
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'test/test.csv')).upload_file('test.csv')
s3_input_test = sagemaker.session.s3_input(s3_data = 's3://{}/{}/test'.format(bucket_name,prefix), content_type='csv')
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
container = get_image_uri(boto3.Session().region_name, 'xgboost', repo_version='1.0-1')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
container
# Out:
# '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3'

# %%
hp = {'max_depth':'5','eta':'0.2','gamma':'4','min_child_weight':'5','subsample':'0.7','objective':'binary:logistic','num_round' : '1000'}

# %%
estimator = sagemaker.estimator.Estimator(image_uri = container,hyperparameters=hp,role=sagemaker.get_execution_role(),
                                         train_instance_count=1,train_instance_type='ml.m5.2xlarge',
                                         train_volume_size=5,output_path=op_path, train_use_spot_instances=True,train_max_run=200,
                                         train_max_wait=500)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_run has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_use_spot_instances has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_wait has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_volume_size has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'train':s3_input_train, 'validation':s3_input_test})
# Out:
# 2021-11-26 05:16:50 Starting - Starting the training job...
# 2021-11-26 05:17:13 Starting - Launching requested ML instancesProfilerReport-1637903810: InProgress
# ...
# 2021-11-26 05:17:50 Starting - Preparing the instances for training.........
# 2021-11-26 05:19:21 Downloading - Downloading input data...
# 2021-11-26 05:19:39 Training - Downloading the training image..INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [05:19:57] 8000x8 matrix with 64000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [05:19:57] 2000x8 matrix with 16000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Train matrix has 8000 rows
# INFO:root:Validation matrix has 2000 rows
# [05:19:57] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [0]#011train-error:0.14950#011validation-error:0.14400
# [1]#011train-error:0.14625#011validation-error:0.13950
# [2]#011train-error:0.14550#011validation-error:0.14000
# [3]#011train-error:0.14525#011validation-error:0.14200
# [4]#011train-error:0.14438#011validation-error:0.14050
# [5]#011train-error:0.14450#011validation-error:0.13800
# [6]#011train-error:0.14488#011validation-error:0.13950
# [7]#011train-error:0.14475#011validation-error:0.14050
# [8]#011train-error:0.14450#011validation-error:0.13950
# [9]#011train-error:0.14400#011validation-error:0.14000
# [10]#011train-error:0.14375#011validation-error:0.13950
# [11]#011train-error:0.14463#011validation-error:0.14050
# [12]#011train-error:0.14400#011validation-error:0.13750
# [13]#011train-error:0.14388#011validation-error:0.13750
# [14]#011train-error:0.14338#011validation-error:0.13800
# [15]#011train-error:0.14275#011validation-error:0.13750
# [16]#011train-error:0.14250#011validation-error:0.13750
# [17]#011train-error:0.14200#011validation-error:0.13450
# [18]#011train-error:0.14037#011validation-error:0.13550
# [19]#011train-error:0.13950#011validation-error:0.13500
# [20]#011train-error:0.14025#011validation-error:0.13550
# [21]#011train-error:0.13950#011validation-error:0.13650
# [22]#011train-error:0.13950#011validation-error:0.13800
# [23]#011train-error:0.13900#011validation-error:0.13600
# [24]#011train-error:0.13875#011validation-error:0.13500
# [25]#011train-error:0.13875#011validation-error:0.13450
# [26]#011train-error:0.13887#011validation-error:0.13500
# [27]#011train-error:0.13837#011validation-error:0.13650
# [28]#011train-error:0.13725#011validation-error:0.13650
# [29]#011train-error:0.13712#011validation-error:0.13600
# [30]#011train-error:0.13712#011validation-error:0.13650
# [31]#011train-error:0.13562#011validation-error:0.13650
# [32]#011train-error:0.13562#011validation-error:0.13650
# [33]#011train-error:0.13537#011validation-error:0.13500
# [34]#011train-error:0.13537#011validation-error:0.13600
# [35]#011train-error:0.13450#011validation-error:0.13300
# [36]#011train-error:0.13475#011validation-error:0.13400
# [37]#011train-error:0.13387#011validation-error:0.13550
# [38]#011train-error:0.13412#011validation-error:0.13600
# [39]#011train-error:0.13350#011validation-error:0.13600
# [40]#011train-error:0.13287#011validation-error:0.13600
# [41]#011train-error:0.13362#011validation-error:0.13600
# [42]#011train-error:0.13200#011validation-error:0.13600
# [43]#011train-error:0.13237#011validation-error:0.13550
# [44]#011train-error:0.13212#011validation-error:0.13550
# [45]#011train-error:0.13112#011validation-error:0.13500
# [46]#011train-error:0.13125#011validation-error:0.13550
# [47]#011train-error:0.13125#011validation-error:0.13550
# [48]#011train-error:0.13125#011validation-error:0.13450
# [49]#011train-error:0.13112#011validation-error:0.13450
# [50]#011train-error:0.13100#011validation-error:0.13400
# [51]#011train-error:0.13000#011validation-error:0.13400
# [52]#011train-error:0.12987#011validation-error:0.13500
# [53]#011train-error:0.12900#011validation-error:0.13600
# [54]#011train-error:0.12962#011validation-error:0.13400
# [55]#011train-error:0.12925#011validation-error:0.13500
# [56]#011train-error:0.12950#011validation-error:0.13550
# [57]#011train-error:0.12937#011validation-error:0.13400
# [58]#011train-error:0.12912#011validation-error:0.13500
# [59]#011train-error:0.12937#011validation-error:0.13500
# [60]#011train-error:0.12887#011validation-error:0.13500
# [61]#011train-error:0.12862#011validation-error:0.13500
# [62]#011train-error:0.12862#011validation-error:0.13550
# [63]#011train-error:0.12850#011validation-error:0.13500
# [64]#011train-error:0.12812#011validation-error:0.13450
# [65]#011train-error:0.12850#011validation-error:0.13250
# [66]#011train-error:0.12812#011validation-error:0.13750
# [67]#011train-error:0.12812#011validation-error:0.13800
# [68]#011train-error:0.12725#011validation-error:0.13700
# [69]#011train-error:0.12725#011validation-error:0.13550
# [70]#011train-error:0.12687#011validation-error:0.13550
# [71]#011train-error:0.12662#011validation-error:0.13500
# [72]#011train-error:0.12675#011validation-error:0.13500
# [73]#011train-error:0.12637#011validation-error:0.13450
# [74]#011train-error:0.12637#011validation-error:0.13450
# [75]#011train-error:0.12662#011validation-error:0.13600
# [76]#011train-error:0.12700#011validation-error:0.13500
# [77]#011train-error:0.12687#011validation-error:0.13500
# [78]#011train-error:0.12725#011validation-error:0.13600
# [79]#011train-error:0.12637#011validation-error:0.13550
# [80]#011train-error:0.12562#011validation-error:0.13500
# [81]#011train-error:0.12587#011validation-error:0.13500
# [82]#011train-error:0.12562#011validation-error:0.13550
# [83]#011train-error:0.12550#011validation-error:0.13500
# [84]#011train-error:0.12450#011validation-error:0.13750
# [85]#011train-error:0.12425#011validation-error:0.13850
# [86]#011train-error:0.12350#011validation-error:0.13800
# [87]#011train-error:0.12337#011validation-error:0.13800
# [88]#011train-error:0.12312#011validation-error:0.14100
# [89]#011train-error:0.12325#011validation-error:0.14100
# [90]#011train-error:0.12225#011validation-error:0.13800
# [91]#011train-error:0.12237#011validation-error:0.13850
# [92]#011train-error:0.12225#011validation-error:0.13850
# [93]#011train-error:0.12225#011validation-error:0.13700
# [94]#011train-error:0.12225#011validation-error:0.13700
# [95]#011train-error:0.12187#011validation-error:0.13800
# [96]#011train-error:0.12212#011validation-error:0.14000
# [97]#011train-error:0.12225#011validation-error:0.13800
# [98]#011train-error:0.12262#011validation-error:0.13850
# [99]#011train-error:0.12212#011validation-error:0.13900
# [100]#011train-error:0.12275#011validation-error:0.14150
# [101]#011train-error:0.12237#011validation-error:0.14250
# [102]#011train-error:0.12212#011validation-error:0.14250
# [103]#011train-error:0.12187#011validation-error:0.14200
# [104]#011train-error:0.12150#011validation-error:0.14200
# [105]#011train-error:0.12225#011validation-error:0.14000
# [106]#011train-error:0.12200#011validation-error:0.14000
# [107]#011train-error:0.12200#011validation-error:0.14050
# [108]#011train-error:0.12137#011validation-error:0.14050
# [109]#011train-error:0.12100#011validation-error:0.14000
# [110]#011train-error:0.12250#011validation-error:0.14050
# [111]#011train-error:0.12237#011validation-error:0.14050
# [112]#011train-error:0.12237#011validation-error:0.14050
# [113]#011train-error:0.12200#011validation-error:0.14000
# [114]#011train-error:0.12187#011validation-error:0.13900
# [115]#011train-error:0.12125#011validation-error:0.13950
# [116]#011train-error:0.12162#011validation-error:0.13950
# [117]#011train-error:0.12150#011validation-error:0.14000
# [118]#011train-error:0.12175#011validation-error:0.13900
# [119]#011train-error:0.12112#011validation-error:0.13900
# [120]#011train-error:0.12150#011validation-error:0.13900
# [121]#011train-error:0.12150#011validation-error:0.13900
# [122]#011train-error:0.12212#011validation-error:0.13900
# [123]#011train-error:0.12200#011validation-error:0.13950
# [124]#011train-error:0.12087#011validation-error:0.14000
# [125]#011train-error:0.12050#011validation-error:0.14100
# [126]#011train-error:0.12062#011validation-error:0.14100
# [127]#011train-error:0.12062#011validation-error:0.14050
# [128]#011train-error:0.12050#011validation-error:0.14000
# [129]#011train-error:0.12050#011validation-error:0.14050
# [130]#011train-error:0.12000#011validation-error:0.13900
# [131]#011train-error:0.11975#011validation-error:0.14100
# [132]#011train-error:0.11925#011validation-error:0.13900
# [133]#011train-error:0.11925#011validation-error:0.13900
# [134]#011train-error:0.11875#011validation-error:0.13750
# [135]#011train-error:0.11850#011validation-error:0.13750
# [136]#011train-error:0.11850#011validation-error:0.13550
# [137]#011train-error:0.11850#011validation-error:0.13550
# [138]#011train-error:0.11775#011validation-error:0.13550
# [139]#011train-error:0.11800#011validation-error:0.13500
# [140]#011train-error:0.11850#011validation-error:0.13400
# [141]#011train-error:0.11688#011validation-error:0.13650
# [142]#011train-error:0.11762#011validation-error:0.13700
# [143]#011train-error:0.11700#011validation-error:0.13800
# [144]#011train-error:0.11575#011validation-error:0.13900
# [145]#011train-error:0.11575#011validation-error:0.13850
# [146]#011train-error:0.11538#011validation-error:0.13950
# [147]#011train-error:0.11463#011validation-error:0.13950
# [148]#011train-error:0.11525#011validation-error:0.13800
# [149]#011train-error:0.11425#011validation-error:0.14150
# [150]#011train-error:0.11425#011validation-error:0.14200
# [151]#011train-error:0.11425#011validation-error:0.14200
# [152]#011train-error:0.11425#011validation-error:0.14250
# [153]#011train-error:0.11438#011validation-error:0.14100
# [154]#011train-error:0.11388#011validation-error:0.14050
# [155]#011train-error:0.11400#011validation-error:0.14050
# [156]#011train-error:0.11325#011validation-error:0.14200
# [157]#011train-error:0.11425#011validation-error:0.14500
# [158]#011train-error:0.11413#011validation-error:0.14400
# [159]#011train-error:0.11400#011validation-error:0.14400
# [160]#011train-error:0.11400#011validation-error:0.14350
# [161]#011train-error:0.11338#011validation-error:0.14450
# [162]#011train-error:0.11350#011validation-error:0.14400
# [163]#011train-error:0.11350#011validation-error:0.14450
# [164]#011train-error:0.11338#011validation-error:0.14450
# [165]#011train-error:0.11338#011validation-error:0.14450
# [166]#011train-error:0.11375#011validation-error:0.14450
# [167]#011train-error:0.11325#011validation-error:0.14500
# [168]#011train-error:0.11338#011validation-error:0.14550
# [169]#011train-error:0.11300#011validation-error:0.14450
# [170]#011train-error:0.11325#011validation-error:0.14500
# [171]#011train-error:0.11300#011validation-error:0.14450
# [172]#011train-error:0.11300#011validation-error:0.14450
# [173]#011train-error:0.11275#011validation-error:0.14500
# [174]#011train-error:0.11275#011validation-error:0.14600
# [175]#011train-error:0.11213#011validation-error:0.14550
# [176]#011train-error:0.11213#011validation-error:0.14550
# [177]#011train-error:0.11125#011validation-error:0.14550
# [178]#011train-error:0.11150#011validation-error:0.14500
# [179]#011train-error:0.11200#011validation-error:0.14600
# [180]#011train-error:0.11200#011validation-error:0.14650
# [181]#011train-error:0.11200#011validation-error:0.14650
# [182]#011train-error:0.11150#011validation-error:0.14450
# [183]#011train-error:0.11188#011validation-error:0.14400
# [184]#011train-error:0.11188#011validation-error:0.14400
# [185]#011train-error:0.11225#011validation-error:0.14350
# [186]#011train-error:0.11200#011validation-error:0.14450
# [187]#011train-error:0.11225#011validation-error:0.14300
# [188]#011train-error:0.11125#011validation-error:0.14400
# [189]#011train-error:0.11113#011validation-error:0.14400
# [190]#011train-error:0.11088#011validation-error:0.14450
# [191]#011train-error:0.11038#011validation-error:0.14400
# [192]#011train-error:0.11063#011validation-error:0.14600
# [193]#011train-error:0.11075#011validation-error:0.14550
# [194]#011train-error:0.11100#011validation-error:0.14550
# [195]#011train-error:0.11063#011validation-error:0.14550
# [196]#011train-error:0.11013#011validation-error:0.14500
# [197]#011train-error:0.11063#011validation-error:0.14550
# [198]#011train-error:0.11100#011validation-error:0.14550
# [199]#011train-error:0.11050#011validation-error:0.14450
# [200]#011train-error:0.11050#011validation-error:0.14450
# [201]#011train-error:0.11050#011validation-error:0.14650
# [202]#011train-error:0.11075#011validation-error:0.14600
# [203]#011train-error:0.11038#011validation-error:0.14650
# [204]#011train-error:0.11025#011validation-error:0.14700
# [205]#011train-error:0.11025#011validation-error:0.14700
# [206]#011train-error:0.11000#011validation-error:0.14750
# [207]#011train-error:0.10900#011validation-error:0.14750
# [208]#011train-error:0.10887#011validation-error:0.14800
# [209]#011train-error:0.10850#011validation-error:0.14700
# [210]#011train-error:0.10850#011validation-error:0.14700
# [211]#011train-error:0.10862#011validation-error:0.14550
# [212]#011train-error:0.10862#011validation-error:0.14550
# [213]#011train-error:0.10875#011validation-error:0.14400
# [214]#011train-error:0.10862#011validation-error:0.14450
# [215]#011train-error:0.10837#011validation-error:0.14350
# [216]#011train-error:0.10850#011validation-error:0.14400
# [217]#011train-error:0.10812#011validation-error:0.14500
# [218]#011train-error:0.10787#011validation-error:0.14450
# [219]#011train-error:0.10800#011validation-error:0.14500
# [220]#011train-error:0.10737#011validation-error:0.14550
# [221]#011train-error:0.10800#011validation-error:0.14500
# [222]#011train-error:0.10787#011validation-error:0.14600
# [223]#011train-error:0.10800#011validation-error:0.14700
# [224]#011train-error:0.10725#011validation-error:0.14700
# [225]#011train-error:0.10725#011validation-error:0.14700
# [226]#011train-error:0.10775#011validation-error:0.14700
# [227]#011train-error:0.10775#011validation-error:0.14700
# [228]#011train-error:0.10812#011validation-error:0.14650
# [229]#011train-error:0.10750#011validation-error:0.14600
# [230]#011train-error:0.10762#011validation-error:0.14350
# [231]#011train-error:0.10712#011validation-error:0.14500
# [232]#011train-error:0.10637#011validation-error:0.14500
# [233]#011train-error:0.10675#011validation-error:0.14550
# [234]#011train-error:0.10650#011validation-error:0.14550
# [235]#011train-error:0.10625#011validation-error:0.14550
# [236]#011train-error:0.10700#011validation-error:0.14550
# [237]#011train-error:0.10575#011validation-error:0.14550
# [238]#011train-error:0.10600#011validation-error:0.14600
# [239]#011train-error:0.10700#011validation-error:0.14700
# [240]#011train-error:0.10712#011validation-error:0.14700
# [241]#011train-error:0.10712#011validation-error:0.14700
# [242]#011train-error:0.10712#011validation-error:0.14500
# [243]#011train-error:0.10687#011validation-error:0.14600
# [244]#011train-error:0.10675#011validation-error:0.14550
# [245]#011train-error:0.10687#011validation-error:0.14550
# [246]#011train-error:0.10687#011validation-error:0.14550
# [247]#011train-error:0.10712#011validation-error:0.14550
# [248]#011train-error:0.10675#011validation-error:0.14600
# [249]#011train-error:0.10650#011validation-error:0.14550
# [250]#011train-error:0.10637#011validation-error:0.14700
# [251]#011train-error:0.10562#011validation-error:0.14750
# [252]#011train-error:0.10575#011validation-error:0.14700
# [253]#011train-error:0.10550#011validation-error:0.14800
# [254]#011train-error:0.10550#011validation-error:0.14800
# [255]#011train-error:0.10562#011validation-error:0.14650
# [256]#011train-error:0.10575#011validation-error:0.14650
# [257]#011train-error:0.10575#011validation-error:0.14550
# [258]#011train-error:0.10500#011validation-error:0.14500
# [259]#011train-error:0.10462#011validation-error:0.14600
# [260]#011train-error:0.10462#011validation-error:0.14600
# [261]#011train-error:0.10487#011validation-error:0.14500
# [262]#011train-error:0.10475#011validation-error:0.14500
# [263]#011train-error:0.10512#011validation-error:0.14600
# [264]#011train-error:0.10562#011validation-error:0.14650
# [265]#011train-error:0.10550#011validation-error:0.14650
# [266]#011train-error:0.10475#011validation-error:0.14700
# [267]#011train-error:0.10450#011validation-error:0.14800
# [268]#011train-error:0.10450#011validation-error:0.14750
# [269]#011train-error:0.10437#011validation-error:0.14750
# [270]#011train-error:0.10437#011validation-error:0.14850
# [271]#011train-error:0.10412#011validation-error:0.14800
# [272]#011train-error:0.10375#011validation-error:0.14750
# [273]#011train-error:0.10450#011validation-error:0.14800
# [274]#011train-error:0.10425#011validation-error:0.14800
# [275]#011train-error:0.10450#011validation-error:0.14800
# [276]#011train-error:0.10500#011validation-error:0.14750
# [277]#011train-error:0.10475#011validation-error:0.14750
# [278]#011train-error:0.10475#011validation-error:0.14750
# [279]#011train-error:0.10400#011validation-error:0.14800
# [280]#011train-error:0.10425#011validation-error:0.14700
# [281]#011train-error:0.10400#011validation-error:0.14700
# [282]#011train-error:0.10400#011validation-error:0.14750
# [283]#011train-error:0.10425#011validation-error:0.14750
# [284]#011train-error:0.10412#011validation-error:0.14700
# [285]#011train-error:0.10412#011validation-error:0.14800
# [286]#011train-error:0.10350#011validation-error:0.14750
# [287]#011train-error:0.10350#011validation-error:0.14750
# [288]#011train-error:0.10362#011validation-error:0.14800
# [289]#011train-error:0.10312#011validation-error:0.14700
# [290]#011train-error:0.10312#011validation-error:0.14700
# [291]#011train-error:0.10300#011validation-error:0.14600
# [292]#011train-error:0.10275#011validation-error:0.14800
# [293]#011train-error:0.10300#011validation-error:0.14750
# [294]#011train-error:0.10300#011validation-error:0.14800
# [295]#011train-error:0.10312#011validation-error:0.14750
# [296]#011train-error:0.10337#011validation-error:0.14800
# [297]#011train-error:0.10337#011validation-error:0.14800
# [298]#011train-error:0.10350#011validation-error:0.14700
# [299]#011train-error:0.10350#011validation-error:0.14750
# [300]#011train-error:0.10275#011validation-error:0.14800
# [301]#011train-error:0.10250#011validation-error:0.14800
# [302]#011train-error:0.10275#011validation-error:0.14700
# [303]#011train-error:0.10275#011validation-error:0.14750
# [304]#011train-error:0.10250#011validation-error:0.14800
# [305]#011train-error:0.10287#011validation-error:0.14800
# [306]#011train-error:0.10287#011validation-error:0.14800
# [307]#011train-error:0.10312#011validation-error:0.14800
# [308]#011train-error:0.10312#011validation-error:0.14800
# [309]#011train-error:0.10312#011validation-error:0.14700
# [310]#011train-error:0.10362#011validation-error:0.14750
# [311]#011train-error:0.10350#011validation-error:0.14800
# [312]#011train-error:0.10350#011validation-error:0.14750
# [313]#011train-error:0.10325#011validation-error:0.14650
# [314]#011train-error:0.10312#011validation-error:0.14700
# [315]#011train-error:0.10312#011validation-error:0.14700
# [316]#011train-error:0.10250#011validation-error:0.14700
# [317]#011train-error:0.10262#011validation-error:0.14700
# [318]#011train-error:0.10287#011validation-error:0.14750
# [319]#011train-error:0.10300#011validation-error:0.14750
# [320]#011train-error:0.10275#011validation-error:0.14750
# [321]#011train-error:0.10300#011validation-error:0.14700
# [322]#011train-error:0.10287#011validation-error:0.14700
# [323]#011train-error:0.10275#011validation-error:0.14650
# [324]#011train-error:0.10287#011validation-error:0.14750
# [325]#011train-error:0.10300#011validation-error:0.14750
# [326]#011train-error:0.10250#011validation-error:0.14750
# [327]#011train-error:0.10275#011validation-error:0.14700
# [328]#011train-error:0.10262#011validation-error:0.14800
# [329]#011train-error:0.10250#011validation-error:0.14800
# [330]#011train-error:0.10250#011validation-error:0.14950
# [331]#011train-error:0.10250#011validation-error:0.14800
# [332]#011train-error:0.10262#011validation-error:0.14700
# [333]#011train-error:0.10237#011validation-error:0.14750
# [334]#011train-error:0.10300#011validation-error:0.14750
# [335]#011train-error:0.10250#011validation-error:0.14700
# [336]#011train-error:0.10225#011validation-error:0.14700
# [337]#011train-error:0.10150#011validation-error:0.14750
# [338]#011train-error:0.10200#011validation-error:0.14700
# [339]#011train-error:0.10200#011validation-error:0.14750
# [340]#011train-error:0.10200#011validation-error:0.14750
# [341]#011train-error:0.10150#011validation-error:0.14650
# [342]#011train-error:0.10100#011validation-error:0.14800
# [343]#011train-error:0.10113#011validation-error:0.14750
# [344]#011train-error:0.10100#011validation-error:0.14750
# [345]#011train-error:0.10088#011validation-error:0.14700
# [346]#011train-error:0.10088#011validation-error:0.14750
# [347]#011train-error:0.10075#011validation-error:0.14700
# [348]#011train-error:0.10088#011validation-error:0.14700
# [349]#011train-error:0.10150#011validation-error:0.14800
# [350]#011train-error:0.10187#011validation-error:0.14900
# [351]#011train-error:0.10162#011validation-error:0.14750
# [352]#011train-error:0.10138#011validation-error:0.14750
# [353]#011train-error:0.10150#011validation-error:0.14750
# [354]#011train-error:0.10162#011validation-error:0.14750
# [355]#011train-error:0.10100#011validation-error:0.14750
# [356]#011train-error:0.10100#011validation-error:0.14850
# [357]#011train-error:0.10075#011validation-error:0.15000
# [358]#011train-error:0.10088#011validation-error:0.15000
# [359]#011train-error:0.10100#011validation-error:0.15000
# [360]#011train-error:0.10150#011validation-error:0.14800
# [361]#011train-error:0.10075#011validation-error:0.14800
# [362]#011train-error:0.10100#011validation-error:0.14700
# [363]#011train-error:0.10113#011validation-error:0.14700
# [364]#011train-error:0.10100#011validation-error:0.14550
# [365]#011train-error:0.10050#011validation-error:0.14650
# [366]#011train-error:0.10075#011validation-error:0.14600
# [367]#011train-error:0.10075#011validation-error:0.14600
# [368]#011train-error:0.10050#011validation-error:0.14650
# [369]#011train-error:0.10063#011validation-error:0.14550
# [370]#011train-error:0.10025#011validation-error:0.14450
# [371]#011train-error:0.10025#011validation-error:0.14550
# [372]#011train-error:0.09963#011validation-error:0.14900
# [373]#011train-error:0.09988#011validation-error:0.14850
# [374]#011train-error:0.09988#011validation-error:0.14850
# [375]#011train-error:0.09975#011validation-error:0.14850
# [376]#011train-error:0.10013#011validation-error:0.14850
# [377]#011train-error:0.10000#011validation-error:0.14900
# [378]#011train-error:0.10013#011validation-error:0.14900
# [379]#011train-error:0.09963#011validation-error:0.14900
# [380]#011train-error:0.09925#011validation-error:0.14900
# [381]#011train-error:0.09913#011validation-error:0.14900
# [382]#011train-error:0.10025#011validation-error:0.14850
# [383]#011train-error:0.10013#011validation-error:0.14850
# [384]#011train-error:0.10013#011validation-error:0.14850
# [385]#011train-error:0.10038#011validation-error:0.14650
# [386]#011train-error:0.09988#011validation-error:0.14550
# [387]#011train-error:0.09988#011validation-error:0.14650
# [388]#011train-error:0.10025#011validation-error:0.14600
# [389]#011train-error:0.10013#011validation-error:0.14550
# [390]#011train-error:0.10088#011validation-error:0.14450
# [391]#011train-error:0.10075#011validation-error:0.14550
# [392]#011train-error:0.10075#011validation-error:0.14550
# [393]#011train-error:0.10113#011validation-error:0.14650
# [394]#011train-error:0.10113#011validation-error:0.14650
# [395]#011train-error:0.10075#011validation-error:0.14500
# [396]#011train-error:0.10075#011validation-error:0.14500
# [397]#011train-error:0.10025#011validation-error:0.14600
# [398]#011train-error:0.09975#011validation-error:0.14650
# [399]#011train-error:0.09888#011validation-error:0.14450
# [400]#011train-error:0.09850#011validation-error:0.14650
# [401]#011train-error:0.09875#011validation-error:0.14550
# [402]#011train-error:0.09913#011validation-error:0.14600
# [403]#011train-error:0.09900#011validation-error:0.14600
# [404]#011train-error:0.09875#011validation-error:0.14650
# [405]#011train-error:0.09850#011validation-error:0.14700
# [406]#011train-error:0.09913#011validation-error:0.14750
# [407]#011train-error:0.09838#011validation-error:0.14800
# [408]#011train-error:0.09850#011validation-error:0.14900
# [409]#011train-error:0.09813#011validation-error:0.14950
# [410]#011train-error:0.09813#011validation-error:0.14950
# [411]#011train-error:0.09800#011validation-error:0.14900
# [412]#011train-error:0.09813#011validation-error:0.14950
# [413]#011train-error:0.09813#011validation-error:0.14900
# [414]#011train-error:0.09800#011validation-error:0.14950
# [415]#011train-error:0.09800#011validation-error:0.14950
# [416]#011train-error:0.09813#011validation-error:0.14950
# [417]#011train-error:0.09813#011validation-error:0.15100
# [418]#011train-error:0.09825#011validation-error:0.15100
# [419]#011train-error:0.09813#011validation-error:0.15100
# [420]#011train-error:0.09813#011validation-error:0.15100
# [421]#011train-error:0.09813#011validation-error:0.15150
# [422]#011train-error:0.09775#011validation-error:0.15100
# [423]#011train-error:0.09775#011validation-error:0.15150
# [424]#011train-error:0.09713#011validation-error:0.15200
# [425]#011train-error:0.09725#011validation-error:0.15100
# [426]#011train-error:0.09750#011validation-error:0.15150
# [427]#011train-error:0.09750#011validation-error:0.15150
# [428]#011train-error:0.09750#011validation-error:0.15150
# [429]#011train-error:0.09750#011validation-error:0.15150
# [430]#011train-error:0.09750#011validation-error:0.15150
# [431]#011train-error:0.09750#011validation-error:0.15100
# [432]#011train-error:0.09738#011validation-error:0.15100
# [433]#011train-error:0.09763#011validation-error:0.15100
# [434]#011train-error:0.09763#011validation-error:0.15100
# [435]#011train-error:0.09713#011validation-error:0.15000
# [436]#011train-error:0.09663#011validation-error:0.14950
# [437]#011train-error:0.09675#011validation-error:0.15050
# [438]#011train-error:0.09675#011validation-error:0.15050
# [439]#011train-error:0.09675#011validation-error:0.15050
# [440]#011train-error:0.09613#011validation-error:0.14950
# [441]#011train-error:0.09600#011validation-error:0.14900
# [442]#011train-error:0.09613#011validation-error:0.14900
# [443]#011train-error:0.09613#011validation-error:0.14900
# [444]#011train-error:0.09600#011validation-error:0.14900
# [445]#011train-error:0.09613#011validation-error:0.15000
# [446]#011train-error:0.09625#011validation-error:0.15000
# [447]#011train-error:0.09625#011validation-error:0.14950
# [448]#011train-error:0.09625#011validation-error:0.14950
# [449]#011train-error:0.09638#011validation-error:0.15000
# [450]#011train-error:0.09625#011validation-error:0.15000
# [451]#011train-error:0.09613#011validation-error:0.15000
# [452]#011train-error:0.09625#011validation-error:0.15000
# [453]#011train-error:0.09638#011validation-error:0.14950
# [454]#011train-error:0.09638#011validation-error:0.14950
# [455]#011train-error:0.09663#011validation-error:0.15050
# [456]#011train-error:0.09613#011validation-error:0.15000
# [457]#011train-error:0.09600#011validation-error:0.14800
# [458]#011train-error:0.09600#011validation-error:0.14800
# [459]#011train-error:0.09600#011validation-error:0.14800
# [460]#011train-error:0.09600#011validation-error:0.14800
# [461]#011train-error:0.09600#011validation-error:0.14800
# [462]#011train-error:0.09600#011validation-error:0.14800
# [463]#011train-error:0.09600#011validation-error:0.14800
# [464]#011train-error:0.09663#011validation-error:0.14800
# [465]#011train-error:0.09600#011validation-error:0.14950
# [466]#011train-error:0.09638#011validation-error:0.14850
# [467]#011train-error:0.09688#011validation-error:0.14900
# [468]#011train-error:0.09688#011validation-error:0.14850
# [469]#011train-error:0.09563#011validation-error:0.14950
# [470]#011train-error:0.09613#011validation-error:0.14750
# [471]#011train-error:0.09575#011validation-error:0.14900
# [472]#011train-error:0.09563#011validation-error:0.14900
# [473]#011train-error:0.09563#011validation-error:0.14900
# [474]#011train-error:0.09525#011validation-error:0.14800
# [475]#011train-error:0.09525#011validation-error:0.14850
# [476]#011train-error:0.09513#011validation-error:0.14850
# [477]#011train-error:0.09538#011validation-error:0.14850
# [478]#011train-error:0.09563#011validation-error:0.14900
# [479]#011train-error:0.09525#011validation-error:0.14900
# [480]#011train-error:0.09550#011validation-error:0.15050
# [481]#011train-error:0.09513#011validation-error:0.15050
# [482]#011train-error:0.09475#011validation-error:0.15050
# [483]#011train-error:0.09500#011validation-error:0.15000
# [484]#011train-error:0.09513#011validation-error:0.14950
# [485]#011train-error:0.09525#011validation-error:0.15000
# [486]#011train-error:0.09550#011validation-error:0.15000
# [487]#011train-error:0.09525#011validation-error:0.14800
# [488]#011train-error:0.09525#011validation-error:0.14800
# [489]#011train-error:0.09513#011validation-error:0.14800
# [490]#011train-error:0.09513#011validation-error:0.14800
# [491]#011train-error:0.09475#011validation-error:0.14850
# [492]#011train-error:0.09500#011validation-error:0.14800
# [493]#011train-error:0.09475#011validation-error:0.14850
# [494]#011train-error:0.09475#011validation-error:0.14850
# [495]#011train-error:0.09500#011validation-error:0.14800
# [496]#011train-error:0.09550#011validation-error:0.14800
# [497]#011train-error:0.09538#011validation-error:0.14850
# [498]#011train-error:0.09513#011validation-error:0.14850
# [499]#011train-error:0.09500#011validation-error:0.15000
# [500]#011train-error:0.09513#011validation-error:0.15000
# [501]#011train-error:0.09488#011validation-error:0.15050
# [502]#011train-error:0.09500#011validation-error:0.15050
# [503]#011train-error:0.09538#011validation-error:0.15050
# [504]#011train-error:0.09525#011validation-error:0.15050
# [505]#011train-error:0.09513#011validation-error:0.14950
# [506]#011train-error:0.09425#011validation-error:0.15000
# [507]#011train-error:0.09438#011validation-error:0.15000
# [508]#011train-error:0.09438#011validation-error:0.15050
# [509]#011train-error:0.09438#011validation-error:0.14950
# [510]#011train-error:0.09438#011validation-error:0.14900
# [511]#011train-error:0.09413#011validation-error:0.14950
# [512]#011train-error:0.09438#011validation-error:0.14950
# [513]#011train-error:0.09450#011validation-error:0.14950
# [514]#011train-error:0.09450#011validation-error:0.14950
# [515]#011train-error:0.09450#011validation-error:0.14950
# [516]#011train-error:0.09413#011validation-error:0.15000
# [517]#011train-error:0.09388#011validation-error:0.15050
# [518]#011train-error:0.09388#011validation-error:0.15050
# [519]#011train-error:0.09400#011validation-error:0.15000
# [520]#011train-error:0.09312#011validation-error:0.15000
# [521]#011train-error:0.09300#011validation-error:0.15000
# [522]#011train-error:0.09312#011validation-error:0.15000
# [523]#011train-error:0.09312#011validation-error:0.15000
# [524]#011train-error:0.09312#011validation-error:0.15050
# [525]#011train-error:0.09375#011validation-error:0.15050
# [526]#011train-error:0.09350#011validation-error:0.15250
# [527]#011train-error:0.09350#011validation-error:0.15250
# [528]#011train-error:0.09312#011validation-error:0.15350
# [529]#011train-error:0.09312#011validation-error:0.15350
# [530]#011train-error:0.09300#011validation-error:0.15300
# [531]#011train-error:0.09300#011validation-error:0.15300
# [532]#011train-error:0.09275#011validation-error:0.15300
# [533]#011train-error:0.09275#011validation-error:0.15250
# [534]#011train-error:0.09375#011validation-error:0.15200
# [535]#011train-error:0.09413#011validation-error:0.15250
# [536]#011train-error:0.09413#011validation-error:0.15150
# [537]#011train-error:0.09362#011validation-error:0.15300
# [538]#011train-error:0.09375#011validation-error:0.15200
# [539]#011train-error:0.09362#011validation-error:0.15300
# [540]#011train-error:0.09362#011validation-error:0.15250
# [541]#011train-error:0.09362#011validation-error:0.15250
# [542]#011train-error:0.09388#011validation-error:0.15250
# [543]#011train-error:0.09375#011validation-error:0.15250
# [544]#011train-error:0.09275#011validation-error:0.15300
# [545]#011train-error:0.09312#011validation-error:0.15500
# [546]#011train-error:0.09300#011validation-error:0.15500
# [547]#011train-error:0.09337#011validation-error:0.15550
# [548]#011train-error:0.09312#011validation-error:0.15500
# [549]#011train-error:0.09312#011validation-error:0.15550
# [550]#011train-error:0.09337#011validation-error:0.15550
# [551]#011train-error:0.09325#011validation-error:0.15450
# [552]#011train-error:0.09325#011validation-error:0.15450
# [553]#011train-error:0.09375#011validation-error:0.15450
# [554]#011train-error:0.09337#011validation-error:0.15400
# [555]#011train-error:0.09337#011validation-error:0.15350
# [556]#011train-error:0.09350#011validation-error:0.15350
# [557]#011train-error:0.09375#011validation-error:0.15450
# [558]#011train-error:0.09312#011validation-error:0.15400
# [559]#011train-error:0.09312#011validation-error:0.15400
# [560]#011train-error:0.09337#011validation-error:0.15400
# [561]#011train-error:0.09312#011validation-error:0.15400
# [562]#011train-error:0.09262#011validation-error:0.15500
# [563]#011train-error:0.09262#011validation-error:0.15500
# [564]#011train-error:0.09287#011validation-error:0.15500
# [565]#011train-error:0.09287#011validation-error:0.15500
# [566]#011train-error:0.09262#011validation-error:0.15500
# [567]#011train-error:0.09262#011validation-error:0.15450
# [568]#011train-error:0.09287#011validation-error:0.15450
# [569]#011train-error:0.09262#011validation-error:0.15450
# [570]#011train-error:0.09250#011validation-error:0.15450
# [571]#011train-error:0.09250#011validation-error:0.15400
# [572]#011train-error:0.09250#011validation-error:0.15350
# [573]#011train-error:0.09262#011validation-error:0.15350
# [574]#011train-error:0.09275#011validation-error:0.15350
# [575]#011train-error:0.09262#011validation-error:0.15350
# [576]#011train-error:0.09312#011validation-error:0.15300
# [577]#011train-error:0.09225#011validation-error:0.15150
# [578]#011train-error:0.09237#011validation-error:0.15150
# [579]#011train-error:0.09237#011validation-error:0.15150
# [580]#011train-error:0.09237#011validation-error:0.15150
# [581]#011train-error:0.09237#011validation-error:0.15150
# [582]#011train-error:0.09225#011validation-error:0.15150
# [583]#011train-error:0.09237#011validation-error:0.15150
# [584]#011train-error:0.09250#011validation-error:0.15150
# [585]#011train-error:0.09225#011validation-error:0.15150
# [586]#011train-error:0.09237#011validation-error:0.15150
# [587]#011train-error:0.09225#011validation-error:0.15100
# [588]#011train-error:0.09225#011validation-error:0.15100
# [589]#011train-error:0.09225#011validation-error:0.15150
# [590]#011train-error:0.09200#011validation-error:0.15100
# [591]#011train-error:0.09187#011validation-error:0.15050
# [592]#011train-error:0.09237#011validation-error:0.15050
# [593]#011train-error:0.09212#011validation-error:0.15050
# [594]#011train-error:0.09237#011validation-error:0.15150
# [595]#011train-error:0.09187#011validation-error:0.15150
# [596]#011train-error:0.09175#011validation-error:0.15200
# [597]#011train-error:0.09187#011validation-error:0.15200
# [598]#011train-error:0.09175#011validation-error:0.15200
# [599]#011train-error:0.09162#011validation-error:0.15250
# [600]#011train-error:0.09125#011validation-error:0.15300
# [601]#011train-error:0.09175#011validation-error:0.15200
# [602]#011train-error:0.09175#011validation-error:0.15300
# [603]#011train-error:0.09175#011validation-error:0.15250
# [604]#011train-error:0.09150#011validation-error:0.15300
# [605]#011train-error:0.09137#011validation-error:0.15300
# [606]#011train-error:0.09175#011validation-error:0.15200
# [607]#011train-error:0.09187#011validation-error:0.15150
# [608]#011train-error:0.09187#011validation-error:0.15150
# [609]#011train-error:0.09175#011validation-error:0.15100
# [610]#011train-error:0.09125#011validation-error:0.15250
# [611]#011train-error:0.09075#011validation-error:0.15350
# [612]#011train-error:0.09125#011validation-error:0.15400
# [613]#011train-error:0.09100#011validation-error:0.15400
# [614]#011train-error:0.09100#011validation-error:0.15400
# [615]#011train-error:0.09100#011validation-error:0.15400
# [616]#011train-error:0.09087#011validation-error:0.15400
# [617]#011train-error:0.09100#011validation-error:0.15400
# [618]#011train-error:0.09100#011validation-error:0.15350
# [619]#011train-error:0.09112#011validation-error:0.15350
# [620]#011train-error:0.09062#011validation-error:0.15300
# [621]#011train-error:0.09087#011validation-error:0.15350
# [622]#011train-error:0.09075#011validation-error:0.15350
# [623]#011train-error:0.09087#011validation-error:0.15350
# [624]#011train-error:0.09087#011validation-error:0.15350
# [625]#011train-error:0.09075#011validation-error:0.15350
# [626]#011train-error:0.09075#011validation-error:0.15350
# [627]#011train-error:0.09087#011validation-error:0.15350
# [628]#011train-error:0.09075#011validation-error:0.15350
# [629]#011train-error:0.09075#011validation-error:0.15350
# [630]#011train-error:0.09150#011validation-error:0.15300
# [631]#011train-error:0.09162#011validation-error:0.15300
# [632]#011train-error:0.09100#011validation-error:0.15250
# [633]#011train-error:0.09075#011validation-error:0.15250
# [634]#011train-error:0.09075#011validation-error:0.15400
# [635]#011train-error:0.09075#011validation-error:0.15400
# [636]#011train-error:0.09050#011validation-error:0.15300
# [637]#011train-error:0.09037#011validation-error:0.15300
# [638]#011train-error:0.09025#011validation-error:0.15300
# [639]#011train-error:0.09025#011validation-error:0.15350
# [640]#011train-error:0.09037#011validation-error:0.15300
# [641]#011train-error:0.09050#011validation-error:0.15300
# [642]#011train-error:0.09037#011validation-error:0.15050
# [643]#011train-error:0.09087#011validation-error:0.14950
# [644]#011train-error:0.09087#011validation-error:0.14900
# [645]#011train-error:0.09025#011validation-error:0.15200
# [646]#011train-error:0.09075#011validation-error:0.15000
# [647]#011train-error:0.09112#011validation-error:0.15100
# [648]#011train-error:0.09087#011validation-error:0.15150
# [649]#011train-error:0.09087#011validation-error:0.15150
# [650]#011train-error:0.09087#011validation-error:0.15150
# [651]#011train-error:0.09087#011validation-error:0.15150
# [652]#011train-error:0.09100#011validation-error:0.15150
# [653]#011train-error:0.09087#011validation-error:0.15150
# [654]#011train-error:0.09075#011validation-error:0.15150
# [655]#011train-error:0.09050#011validation-error:0.15150
# [656]#011train-error:0.09025#011validation-error:0.15200
# [657]#011train-error:0.08975#011validation-error:0.15050
# [658]#011train-error:0.08975#011validation-error:0.15050
# [659]#011train-error:0.09012#011validation-error:0.15050
# [660]#011train-error:0.08925#011validation-error:0.15100
# [661]#011train-error:0.08937#011validation-error:0.15000
# [662]#011train-error:0.08975#011validation-error:0.15000
# [663]#011train-error:0.08950#011validation-error:0.14950
# [664]#011train-error:0.08975#011validation-error:0.15000
# [665]#011train-error:0.08950#011validation-error:0.15150
# [666]#011train-error:0.08950#011validation-error:0.15050
# [667]#011train-error:0.08975#011validation-error:0.15050
# [668]#011train-error:0.08962#011validation-error:0.15050
# [669]#011train-error:0.08975#011validation-error:0.15100
# [670]#011train-error:0.08975#011validation-error:0.15100
# [671]#011train-error:0.08975#011validation-error:0.15100
# [672]#011train-error:0.09087#011validation-error:0.15100
# [673]#011train-error:0.09075#011validation-error:0.15150
# [674]#011train-error:0.09087#011validation-error:0.15200
# [675]#011train-error:0.09062#011validation-error:0.15150
# [676]#011train-error:0.09062#011validation-error:0.15150
# [677]#011train-error:0.09062#011validation-error:0.15200
# [678]#011train-error:0.09062#011validation-error:0.15200
# [679]#011train-error:0.09050#011validation-error:0.15200
# [680]#011train-error:0.09050#011validation-error:0.15200
# [681]#011train-error:0.09112#011validation-error:0.15350
# [682]#011train-error:0.09087#011validation-error:0.15250
# [683]#011train-error:0.09087#011validation-error:0.15250
# [684]#011train-error:0.09100#011validation-error:0.15250
# [685]#011train-error:0.09087#011validation-error:0.15100
# [686]#011train-error:0.09075#011validation-error:0.15100
# [687]#011train-error:0.09062#011validation-error:0.15100
# [688]#011train-error:0.09075#011validation-error:0.15100
# [689]#011train-error:0.09087#011validation-error:0.15050
# [690]#011train-error:0.09075#011validation-error:0.15050
# [691]#011train-error:0.09087#011validation-error:0.15050
# [692]#011train-error:0.09075#011validation-error:0.14950
# [693]#011train-error:0.09037#011validation-error:0.15050
# [694]#011train-error:0.09037#011validation-error:0.15000
# [695]#011train-error:0.09025#011validation-error:0.14900
# [696]#011train-error:0.09012#011validation-error:0.14900
# [697]#011train-error:0.09000#011validation-error:0.14950
# [698]#011train-error:0.09025#011validation-error:0.14900
# [699]#011train-error:0.09037#011validation-error:0.14900
# [700]#011train-error:0.09025#011validation-error:0.14950
# [701]#011train-error:0.09025#011validation-error:0.14950
# [702]#011train-error:0.09025#011validation-error:0.14900
# [703]#011train-error:0.08975#011validation-error:0.14950
# [704]#011train-error:0.08950#011validation-error:0.15050
# [705]#011train-error:0.08962#011validation-error:0.15000
# [706]#011train-error:0.08950#011validation-error:0.15000
# [707]#011train-error:0.09025#011validation-error:0.14950
# [708]#011train-error:0.09025#011validation-error:0.15000
# [709]#011train-error:0.09025#011validation-error:0.15000
# [710]#011train-error:0.09025#011validation-error:0.14950
# [711]#011train-error:0.09037#011validation-error:0.14950
# [712]#011train-error:0.09025#011validation-error:0.14950
# [713]#011train-error:0.09037#011validation-error:0.14950
# [714]#011train-error:0.09025#011validation-error:0.14950
# [715]#011train-error:0.09050#011validation-error:0.14950
# [716]#011train-error:0.09037#011validation-error:0.14950
# [717]#011train-error:0.09025#011validation-error:0.15000
# [718]#011train-error:0.08937#011validation-error:0.14900
# [719]#011train-error:0.08925#011validation-error:0.14900
# [720]#011train-error:0.08937#011validation-error:0.14850
# [721]#011train-error:0.08925#011validation-error:0.14900
# [722]#011train-error:0.08925#011validation-error:0.14900
# [723]#011train-error:0.08925#011validation-error:0.14900
# [724]#011train-error:0.08962#011validation-error:0.14950
# [725]#011train-error:0.08837#011validation-error:0.14950
# [726]#011train-error:0.08837#011validation-error:0.14950
# [727]#011train-error:0.08875#011validation-error:0.15000
# [728]#011train-error:0.08887#011validation-error:0.14950
# [729]#011train-error:0.08862#011validation-error:0.15000
# [730]#011train-error:0.08887#011validation-error:0.14950
# [731]#011train-error:0.08887#011validation-error:0.14950
# [732]#011train-error:0.08887#011validation-error:0.14950
# [733]#011train-error:0.08862#011validation-error:0.15000
# [734]#011train-error:0.08862#011validation-error:0.15000
# [735]#011train-error:0.08862#011validation-error:0.15000
# [736]#011train-error:0.08862#011validation-error:0.14950
# [737]#011train-error:0.08862#011validation-error:0.14850
# [738]#011train-error:0.08862#011validation-error:0.14950
# [739]#011train-error:0.08862#011validation-error:0.14850
# [740]#011train-error:0.08837#011validation-error:0.14900
# [741]#011train-error:0.08862#011validation-error:0.14900
# [742]#011train-error:0.08850#011validation-error:0.14850
# [743]#011train-error:0.08862#011validation-error:0.14900
# [744]#011train-error:0.08837#011validation-error:0.14900
# [745]#011train-error:0.08837#011validation-error:0.14900
# [746]#011train-error:0.08837#011validation-error:0.14900
# [747]#011train-error:0.08787#011validation-error:0.14900
# [748]#011train-error:0.08800#011validation-error:0.14850
# [749]#011train-error:0.08800#011validation-error:0.14850
# [750]#011train-error:0.08687#011validation-error:0.14900
# [751]#011train-error:0.08700#011validation-error:0.14900
# [752]#011train-error:0.08762#011validation-error:0.14950
# [753]#011train-error:0.08737#011validation-error:0.15050
# [754]#011train-error:0.08737#011validation-error:0.15050
# [755]#011train-error:0.08775#011validation-error:0.15150
# [756]#011train-error:0.08775#011validation-error:0.15150
# [757]#011train-error:0.08875#011validation-error:0.15150
# [758]#011train-error:0.08887#011validation-error:0.15150
# [759]#011train-error:0.08875#011validation-error:0.15100
# [760]#011train-error:0.08850#011validation-error:0.15100
# [761]#011train-error:0.08862#011validation-error:0.15100
# [762]#011train-error:0.08812#011validation-error:0.15200
# [763]#011train-error:0.08812#011validation-error:0.15200
# [764]#011train-error:0.08812#011validation-error:0.15200
# [765]#011train-error:0.08812#011validation-error:0.15200
# [766]#011train-error:0.08800#011validation-error:0.15200
# [767]#011train-error:0.08787#011validation-error:0.15200
# [768]#011train-error:0.08787#011validation-error:0.15200
# [769]#011train-error:0.08837#011validation-error:0.15300
# [770]#011train-error:0.08837#011validation-error:0.15300
# [771]#011train-error:0.08837#011validation-error:0.15300
# [772]#011train-error:0.08837#011validation-error:0.15300
# [773]#011train-error:0.08837#011validation-error:0.15300
# [774]#011train-error:0.08812#011validation-error:0.15350
# [775]#011train-error:0.08712#011validation-error:0.15250
# [776]#011train-error:0.08712#011validation-error:0.15250
# [777]#011train-error:0.08712#011validation-error:0.15250
# [778]#011train-error:0.08700#011validation-error:0.15300
# [779]#011train-error:0.08687#011validation-error:0.15100
# [780]#011train-error:0.08750#011validation-error:0.15100
# [781]#011train-error:0.08737#011validation-error:0.15050
# [782]#011train-error:0.08725#011validation-error:0.15100
# [783]#011train-error:0.08662#011validation-error:0.15000
# [784]#011train-error:0.08700#011validation-error:0.15050
# [785]#011train-error:0.08725#011validation-error:0.15100
# [786]#011train-error:0.08687#011validation-error:0.15050
# [787]#011train-error:0.08687#011validation-error:0.15050
# [788]#011train-error:0.08700#011validation-error:0.15050
# [789]#011train-error:0.08700#011validation-error:0.15050
# [790]#011train-error:0.08712#011validation-error:0.15100
# [791]#011train-error:0.08712#011validation-error:0.15050
# [792]#011train-error:0.08712#011validation-error:0.15050
# [793]#011train-error:0.08700#011validation-error:0.15050
# [794]#011train-error:0.08712#011validation-error:0.15050
# [795]#011train-error:0.08625#011validation-error:0.15050
# [796]#011train-error:0.08650#011validation-error:0.15050
# [797]#011train-error:0.08675#011validation-error:0.15100
# [798]#011train-error:0.08675#011validation-error:0.15100
# [799]#011train-error:0.08675#011validation-error:0.15100
# [800]#011train-error:0.08675#011validation-error:0.15100
# [801]#011train-error:0.08675#011validation-error:0.15100
# [802]#011train-error:0.08675#011validation-error:0.15100
# [803]#011train-error:0.08675#011validation-error:0.15100
# [804]#011train-error:0.08675#011validation-error:0.15150
# [805]#011train-error:0.08600#011validation-error:0.15100
# [806]#011train-error:0.08637#011validation-error:0.15150
# [807]#011train-error:0.08637#011validation-error:0.15150
# [808]#011train-error:0.08675#011validation-error:0.15150
# [809]#011train-error:0.08625#011validation-error:0.15050
# [810]#011train-error:0.08625#011validation-error:0.15050
# [811]#011train-error:0.08625#011validation-error:0.15050
# [812]#011train-error:0.08575#011validation-error:0.15100
# [813]#011train-error:0.08513#011validation-error:0.15100
# [814]#011train-error:0.08513#011validation-error:0.15100
# [815]#011train-error:0.08513#011validation-error:0.15100
# [816]#011train-error:0.08513#011validation-error:0.15100
# [817]#011train-error:0.08513#011validation-error:0.15000
# [818]#011train-error:0.08500#011validation-error:0.15100
# [819]#011train-error:0.08488#011validation-error:0.15100
# [820]#011train-error:0.08488#011validation-error:0.15100
# [821]#011train-error:0.08500#011validation-error:0.15100
# [822]#011train-error:0.08500#011validation-error:0.15100
# [823]#011train-error:0.08525#011validation-error:0.15150
# [824]#011train-error:0.08525#011validation-error:0.15150
# [825]#011train-error:0.08525#011validation-error:0.15150
# [826]#011train-error:0.08600#011validation-error:0.15050
# [827]#011train-error:0.08612#011validation-error:0.15100
# [828]#011train-error:0.08612#011validation-error:0.15200
# [829]#011train-error:0.08612#011validation-error:0.15100
# [830]#011train-error:0.08612#011validation-error:0.15100
# [831]#011train-error:0.08575#011validation-error:0.15200
# [832]#011train-error:0.08600#011validation-error:0.15150
# [833]#011train-error:0.08625#011validation-error:0.15300
# [834]#011train-error:0.08625#011validation-error:0.15100
# [835]#011train-error:0.08662#011validation-error:0.15150
# [836]#011train-error:0.08662#011validation-error:0.15150
# [837]#011train-error:0.08700#011validation-error:0.15150
# [838]#011train-error:0.08687#011validation-error:0.15150
# [839]#011train-error:0.08662#011validation-error:0.15150
# [840]#011train-error:0.08625#011validation-error:0.15200
# [841]#011train-error:0.08588#011validation-error:0.15200
# [842]#011train-error:0.08588#011validation-error:0.15200
# [843]#011train-error:0.08575#011validation-error:0.15200
# [844]#011train-error:0.08588#011validation-error:0.15200
# [845]#011train-error:0.08588#011validation-error:0.15150
# [846]#011train-error:0.08625#011validation-error:0.15100
# [847]#011train-error:0.08600#011validation-error:0.15150
# [848]#011train-error:0.08625#011validation-error:0.15150
# [849]#011train-error:0.08588#011validation-error:0.15150
# [850]#011train-error:0.08588#011validation-error:0.15150
# [851]#011train-error:0.08600#011validation-error:0.15250
# [852]#011train-error:0.08563#011validation-error:0.15150
# [853]#011train-error:0.08625#011validation-error:0.15150
# [854]#011train-error:0.08612#011validation-error:0.15200
# [855]#011train-error:0.08563#011validation-error:0.15200
# [856]#011train-error:0.08612#011validation-error:0.15100
# [857]#011train-error:0.08525#011validation-error:0.15100
# [858]#011train-error:0.08513#011validation-error:0.15100
# [859]#011train-error:0.08513#011validation-error:0.15050
# [860]#011train-error:0.08550#011validation-error:0.14950
# [861]#011train-error:0.08525#011validation-error:0.14950
# [862]#011train-error:0.08525#011validation-error:0.14950
# [863]#011train-error:0.08525#011validation-error:0.14950
# [864]#011train-error:0.08538#011validation-error:0.14900
# [865]#011train-error:0.08538#011validation-error:0.14900
# [866]#011train-error:0.08513#011validation-error:0.15150
# [867]#011train-error:0.08525#011validation-error:0.15150
# [868]#011train-error:0.08500#011validation-error:0.15150
# [869]#011train-error:0.08525#011validation-error:0.15200
# [870]#011train-error:0.08500#011validation-error:0.15150
# [871]#011train-error:0.08513#011validation-error:0.15200
# [872]#011train-error:0.08513#011validation-error:0.15200
# [873]#011train-error:0.08500#011validation-error:0.15200
# [874]#011train-error:0.08500#011validation-error:0.15200
# [875]#011train-error:0.08513#011validation-error:0.15200
# [876]#011train-error:0.08500#011validation-error:0.15100
# [877]#011train-error:0.08500#011validation-error:0.15150
# [878]#011train-error:0.08538#011validation-error:0.15050
# [879]#011train-error:0.08525#011validation-error:0.15000
# [880]#011train-error:0.08525#011validation-error:0.15050
# [881]#011train-error:0.08525#011validation-error:0.15050
# [882]#011train-error:0.08525#011validation-error:0.15050
# [883]#011train-error:0.08525#011validation-error:0.15050
# [884]#011train-error:0.08525#011validation-error:0.15050
# [885]#011train-error:0.08538#011validation-error:0.15100
# [886]#011train-error:0.08538#011validation-error:0.15100
# [887]#011train-error:0.08550#011validation-error:0.15150
# [888]#011train-error:0.08500#011validation-error:0.15100
# [889]#011train-error:0.08500#011validation-error:0.15100
# [890]#011train-error:0.08500#011validation-error:0.15100
# [891]#011train-error:0.08488#011validation-error:0.15100
# [892]#011train-error:0.08488#011validation-error:0.15100
# [893]#011train-error:0.08488#011validation-error:0.15250
# [894]#011train-error:0.08488#011validation-error:0.15150
# [895]#011train-error:0.08475#011validation-error:0.15250
# [896]#011train-error:0.08513#011validation-error:0.15350
# [897]#011train-error:0.08513#011validation-error:0.15350
# [898]#011train-error:0.08513#011validation-error:0.15350
# [899]#011train-error:0.08500#011validation-error:0.15250
# [900]#011train-error:0.08488#011validation-error:0.15250
# [901]#011train-error:0.08500#011validation-error:0.15250
# [902]#011train-error:0.08550#011validation-error:0.15250
# [903]#011train-error:0.08538#011validation-error:0.15250
# [904]#011train-error:0.08550#011validation-error:0.15250
# [905]#011train-error:0.08488#011validation-error:0.15250
# [906]#011train-error:0.08488#011validation-error:0.15250
# [907]#011train-error:0.08475#011validation-error:0.15300
# [908]#011train-error:0.08488#011validation-error:0.15300
# [909]#011train-error:0.08488#011validation-error:0.15300
# [910]#011train-error:0.08488#011validation-error:0.15300
# [911]#011train-error:0.08450#011validation-error:0.15450
# [912]#011train-error:0.08475#011validation-error:0.15300
# [913]#011train-error:0.08475#011validation-error:0.15300
# [914]#011train-error:0.08500#011validation-error:0.15100
# [915]#011train-error:0.08500#011validation-error:0.15100
# [916]#011train-error:0.08475#011validation-error:0.15150
# [917]#011train-error:0.08400#011validation-error:0.15150
# [918]#011train-error:0.08375#011validation-error:0.15150
# [919]#011train-error:0.08413#011validation-error:0.15100
# [920]#011train-error:0.08413#011validation-error:0.15100
# [921]#011train-error:0.08425#011validation-error:0.15100
# [922]#011train-error:0.08450#011validation-error:0.15100
# [923]#011train-error:0.08450#011validation-error:0.15100
# [924]#011train-error:0.08450#011validation-error:0.15100
# [925]#011train-error:0.08438#011validation-error:0.15100
# [926]#011train-error:0.08450#011validation-error:0.15100
# [927]#011train-error:0.08413#011validation-error:0.15100
# [928]#011train-error:0.08425#011validation-error:0.15100
# [929]#011train-error:0.08450#011validation-error:0.15100
# [930]#011train-error:0.08413#011validation-error:0.15100
# [931]#011train-error:0.08438#011validation-error:0.15100
# [932]#011train-error:0.08425#011validation-error:0.15100
# [933]#011train-error:0.08450#011validation-error:0.15100
# [934]#011train-error:0.08413#011validation-error:0.15000
# [935]#011train-error:0.08388#011validation-error:0.15050
# [936]#011train-error:0.08400#011validation-error:0.15050
# [937]#011train-error:0.08400#011validation-error:0.15050
# [938]#011train-error:0.08388#011validation-error:0.15050
# [939]#011train-error:0.08400#011validation-error:0.15050
# [940]#011train-error:0.08388#011validation-error:0.15050
# [941]#011train-error:0.08400#011validation-error:0.15050
# [942]#011train-error:0.08388#011validation-error:0.15100
# [943]#011train-error:0.08388#011validation-error:0.15350
# [944]#011train-error:0.08375#011validation-error:0.15300
# [945]#011train-error:0.08375#011validation-error:0.15150
# [946]#011train-error:0.08375#011validation-error:0.15150
# [947]#011train-error:0.08388#011validation-error:0.15050
# [948]#011train-error:0.08388#011validation-error:0.15050
# [949]#011train-error:0.08363#011validation-error:0.15050
# [950]#011train-error:0.08388#011validation-error:0.15050
# [951]#011train-error:0.08363#011validation-error:0.15250
# [952]#011train-error:0.08338#011validation-error:0.15250
# [953]#011train-error:0.08338#011validation-error:0.15350
# [954]#011train-error:0.08363#011validation-error:0.15350
# [955]#011train-error:0.08388#011validation-error:0.15350
# [956]#011train-error:0.08413#011validation-error:0.15350
# [957]#011train-error:0.08388#011validation-error:0.15350
# [958]#011train-error:0.08400#011validation-error:0.15250
# [959]#011train-error:0.08388#011validation-error:0.15350
# [960]#011train-error:0.08413#011validation-error:0.15300
# [961]#011train-error:0.08413#011validation-error:0.15300
# [962]#011train-error:0.08388#011validation-error:0.15350
# [963]#011train-error:0.08363#011validation-error:0.15350
# [964]#011train-error:0.08375#011validation-error:0.15350
# [965]#011train-error:0.08375#011validation-error:0.15400
# [966]#011train-error:0.08350#011validation-error:0.15150
# [967]#011train-error:0.08350#011validation-error:0.15150
# [968]#011train-error:0.08375#011validation-error:0.15200
# [969]#011train-error:0.08375#011validation-error:0.15200
# [970]#011train-error:0.08363#011validation-error:0.15300
# [971]#011train-error:0.08363#011validation-error:0.15300
# [972]#011train-error:0.08363#011validation-error:0.15300
# [973]#011train-error:0.08363#011validation-error:0.15250
# [974]#011train-error:0.08388#011validation-error:0.15250
# [975]#011train-error:0.08363#011validation-error:0.15250
# [976]#011train-error:0.08413#011validation-error:0.15250
# [977]#011train-error:0.08363#011validation-error:0.15250
# [978]#011train-error:0.08388#011validation-error:0.15400
# [979]#011train-error:0.08413#011validation-error:0.15350
# [980]#011train-error:0.08413#011validation-error:0.15400
# [981]#011train-error:0.08413#011validation-error:0.15350
# [982]#011train-error:0.08375#011validation-error:0.15350
# [983]#011train-error:0.08313#011validation-error:0.15350
# [984]#011train-error:0.08300#011validation-error:0.15350
# [985]#011train-error:0.08313#011validation-error:0.15300
# [986]#011train-error:0.08300#011validation-error:0.15350
# [987]#011train-error:0.08313#011validation-error:0.15350
# [988]#011train-error:0.08300#011validation-error:0.15350
# [989]#011train-error:0.08300#011validation-error:0.15400
# [990]#011train-error:0.08300#011validation-error:0.15350
# [991]#011train-error:0.08300#011validation-error:0.15400
# [992]#011train-error:0.08300#011validation-error:0.15400
# [993]#011train-error:0.08300#011validation-error:0.15300
# [994]#011train-error:0.08288#011validation-error:0.15450
# [995]#011train-error:0.08338#011validation-error:0.15450
# [996]#011train-error:0.08338#011validation-error:0.15400
# [997]#011train-error:0.08338#011validation-error:0.15450
# [998]#011train-error:0.08338#011validation-error:0.15500
# [999]#011train-error:0.08338#011validation-error:0.15450
#
# 2021-11-26 05:20:14 Uploading - Uploading generated training model
# 2021-11-26 05:20:34 Completed - Training job completed
# Training seconds: 72
# Billable seconds: 37
# Managed Spot Training savings: 48.6%

# %%
xgb_predictor = estimator.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# ----------!

# %%
from sagemaker.predictor import csv_serializer
test_data_array = test_data.drop(['Exited'],axis=1).values
#xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer
predictions = xgb_predictor.predict(test_data_array, initial_args={'ContentType': 'text/csv'}).decode('utf-8')
predictions_array = np.fromstring(predictions[1:],sep=',')
print(predictions_array.shape)
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# (2000,)

# %%
predictions_array
# Out:
# array([0.22591969, 0.84921354, 0.0093817 , ..., 0.00319957, 0.95756274,
#        0.00371034])

# %%
cm=pd.crosstab(index=test_data['Exited'],columns=np.round(predictions_array),rownames=['Observed'],colnames=['Predicted'])
tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
print("\n{0:<20}{1:<4.1f}%\n".format("overall classification rate:",p))
print("{0:<15}{1:<15}{2:>8}".format("Predicted","Not Exited","Exited"))
print("Observed")
print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("Not Exited", tn/(tn+fn)*100,tn, fp/(tp+fp)*100,fp))
print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("Exited", fn/(tn+fn)*100,fn, fp/(tp+fp)*100,tp))
# Out:
# overall classification rate:84.5%
#
# Predicted      Not Exited       Exited
# Observed
# Not Exited     88% (1505)    35% (101)
# Exited          12% (208)     35% (186)

# %%
# Deleteing the endpoints

# %%
sagemaker.session.Session().delete_endpoint(xgb_predictor.endpoint)
bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
bucket_to_delete.objects.all().delete()
